# %%
cd drive/
# Out:
# /content/drive

# %%
cd MyDrive/Pytorch-nli/
# Out:
# /content/drive/MyDrive/Pytorch-nli

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python train.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Program execution start: 2021-05-15 08:24:02.024782
# split started	done...
# Example:  {'premise': ['a', 'person', 'on', 'a', 'horse', 'jumps', 'over', 'a', 'broken', 'down', 'airplane'], 'hypothesis': ['a', 'person', 'is', 'training', 'his', 'horse', 'for', 'a', 'competition'], 'label': 'neutral'}
# Number of training examples: 549367
# Number of validation examples: 9842
# Number of testing examples: 9824
# Vectors already present...Loading vectors!!!	done...
# Total vocabulary Size is 33520
# Embedding vectors size is 33520
# Dataset preparation done!!! Some overview of the data and tokens are given...
# Topkens with top occurrences!!!
# [('a', 1466132), ('the', 544469), ('in', 415243), ('is', 380073), ('man', 271200), ('on', 240378), ('and', 210549), ('are', 202711), ('of', 196234)]
# [('entailment', 183416), ('contradiction', 183187), ('neutral', 182764)]
# ...

# %%
# !python evaluate.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Program exection starts: 2021-05-15 09:47:30.575799
# data split started
# data split done...
# Example:  {'premise': ['a', 'person', 'on', 'a', 'horse', 'jumps', 'over', 'a', 'broken', 'down', 'airplane'], 'hypothesis': ['a', 'person', 'is', 'training', 'his', 'horse', 'for', 'a', 'competition'], 'label': 'neutral'}
# Number of training examples: 549367
# Number of validation examples: 9842
# Number of testing examples: 9824
# Vectors already present...Loading vectors!!!	done...
# Total vocabulary Size is 33520
# Embedding vectors size is 33520
# resource preparation done: 2021-05-15 09:47:57.521981
# +------------+----------+
# |    data    | accuracy |
# +------------+----------+
# | validation |  83.723  |
# |    test    |  86.843  |
# +------------+----------+
# +---------------+----------+
# |     label     | accuracy |
# +---------------+----------+
# ...
